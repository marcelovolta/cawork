# %%
#Import Libaries
#***************
from datetime import datetime  as dt
import pandas as pd
import re
import math

#Named variables Definition
#**************************
call_rate = 125
form_rate = 125
minimum_call_duration = 60
brand_report_file = "endurance/endurance_brand_report_201908.csv"
ca_report_file = "endurance/endurance_ca_report_201908.csv"
brand_report_separator = ";"

#Field names in Brand Report
brand_report_phone_field_name = 'Phone'
brand_report_uuid_field_name = 'Vendor Id2'
brand_report_email_field_name = 'Email'

#The following are field names for the CA report
#These are not expected to change but I don't want to have to 
#make a massive mod if they do for whatever reason
ca_report_originating_number_field_name = 'originating_number'
ca_report_phone_number_field_name = 'phone_number'
ca_report_phone_form_field_name = 'form_phone'
ca_report_uuid_field_name = 'uuid'
ca_report_email_field_name = 'form_email'
ca_report_referral_path_field_name = 'referral_path'
ca_report_form_referral_path_field_value = 'form'
ca_report_call_referral_path_field_value = 'call'
ca_report_click_referral_path_field_value = 'click'
ca_report_raw_referral_id_field_name = 'raw_referral_id'
ca_report_reason_why_not_billed_field_name = 'reason_why_not_billed'
ca_report_phone_duration_field_name = 'phone_duration'


#Transformation functions
#------------------------

#The clean_US_phone_number function makes the following assumptions
#All numbers belong to the US. We only remove the first character of the phone if it is the US country code: 1
#Number can contain extension numbers and other additional info at the end of the number, and not at the beginning
#This function has a lot of deffensive code
def clean_US_phone_number(text_phone_number):
    
    if pd.isnull(text_phone_number):
        return ''
    
    modified = re.sub("\D+","", str(text_phone_number))
    
    if modified == '':
        return ''

    #Remove the country code
    if modified[0] == '1':
        modified = modified[1:]
    
    #Cover corner case: too few characters
    if len(modified) < 10:
        return modified
    
    #Remove anything else at the end of the number
    modified = modified[:10]
    return modified
    
#The following function is more forgiving in the country code but is unable to remove extension info
def clean_phone_number_no_ext(text_phone_number):
    modified = re.sub("\D+","", str(text_phone_number))
    #Remove the country code
    modified = modified[-10:]
    return modified

def clean_phone_duration(phone_duration):
    if math.isnan(phone_duration):
        return 0
    return int(phone_duration)

def is_blank(myString):
    return not (str(myString) and str(myString).strip())

def is_not_blank(myString):
    return bool(str(myString) and str(myString).strip())

#Valid for Pandas DataFrames
def is_blank_or_nan(myString):
    return not (str(myString) and str(myString).strip() and not pd.isna(myString))

#Valid for Pandas DataFrames
def is_not_blank_or_nan(myString):
    return bool(str(myString) and str(myString).strip() and not pd.isna(myString))


#Data Gathering and Wrangling
#****************************

#Load the files. The brand report comes from an Excel file, whose default separator to export to CSV is ;
#he CA report always comes from a Mode query
ca_report = pd.read_csv(ca_report_file)
ca_report_small = ca_report.iloc[100:120].copy()
print(ca_report_small)
# Out:
#       submitted_cst_date                 campaign_name  raw_referral_id  \
# 100  2019-08-01 00:00:00       Endurance Auto Warranty          7614028
# 101  2019-08-01 00:00:00       Endurance Auto Warranty          7610543
# 102  2019-08-01 00:00:00       Endurance Auto Warranty          7614534
# 103  2019-08-01 00:00:00       Endurance Auto Warranty          7610869
# 104  2019-08-01 00:00:00                  Endurance TV          7615631
# 105  2019-08-01 00:00:00  Endurance Auto Warranty - RL          7610973
# 106  2019-08-01 00:00:00                  Endurance TV          7615637
# 107  2019-08-01 00:00:00       Endurance Auto Warranty          7611091
# 108  2019-08-01 00:00:00       Endurance Auto Warranty          7610858
# 109  2019-08-01 00:00:00       Endurance Auto Warranty          7611500
# 110  2019-08-01 00:00:00  Endurance Auto Warranty - RL          7611886
# 111  2019-08-01 00:00:00       Endurance Auto Warranty          7611529
# 112  2019-08-01 00:00:00       Endurance Auto Warranty          7613125
# 113  2019-08-01 00:00:00       Endurance Auto Warranty          7613957
# 114  2019-08-01 00:00:00  Endurance Auto Warranty - RL          7613140
# 115  2019-08-01 00:00:00       Endurance Auto Warranty          7614440
# 116  2019-08-01 00:00:00       Endurance Auto Warranty          7615308
# 117  2019-08-01 00:00:00       Endurance Auto Warranty          7614882
# 118  2019-08-01 00:00:00       Endurance Auto Warranty          7615524
# 119  2019-08-01 00:00:00       Endurance Auto Warranty          7615425
#
#                                    object  \
# 100                                 My CA
# 101                 My CA - Matching Tool
# 102                          Buyers Guide
# 103                                 My CA
# 104  Unknown (Twilio Attribution=Default)
# 105                  RetirementLiving.com
# 106  Unknown (Twilio Attribution=Default)
# 107                                 My CA
# 108                 My CA - Matching Tool
# 109                 My CA - Matching Tool
# 110                  RetirementLiving.com
# 111                 My CA - Matching Tool
# 112                 My CA - Matching Tool
# 113                 My CA - Matching Tool
# 114                  RetirementLiving.com
# 115                 My CA - Matching Tool
# 116                 My CA - Matching Tool
# 117                 My CA - Matching Tool
# 118                 My CA - Matching Tool
# 119                 My CA - Matching Tool
#
#                                      uuid originating_number  phone_number  \
# 100                                   NaN       +16145600872  1.855707e+10
# 101  c6a73b2e-cafc-4c38-b05e-99a7b2a21ce9                NaN           NaN
# 102                                   NaN       +18086887650  1.877370e+10
# 103  2e7fbc5e-0526-4076-8b82-0204c27cbdc6                NaN           NaN
# 104                                   NaN       +12054851154  1.855879e+10
# 105                                   NaN                NaN           NaN
# 106                                   NaN       +14045528569  1.855879e+10
# 107  769ec98b-546d-4f96-85a2-7a844e7ba119                NaN           NaN
# 108  bc00f6bc-9dfd-49ed-bf67-edf5e68e0aec                NaN           NaN
# 109  036a329f-92a2-4520-9c65-298bbc9e1fb9                NaN           NaN
# 110                                   NaN                NaN           NaN
# 111  1eb0d8f8-f1ed-4740-ba19-cbd148254d42                NaN           NaN
# 112  d922f2f0-70e8-4587-ab9d-83f374ffb6cd                NaN           NaN
# 113  06725269-7a43-408e-8d22-94578d8f48af                NaN           NaN
# 114                                   NaN                NaN           NaN
# 115  593758aa-b9e7-4ad6-b90e-2a3a2cca0b1e                NaN           NaN
# 116  06d4c8ff-476b-4274-830c-c5cfe0d52574                NaN           NaN
# 117  29eef8c8-d412-4b58-9401-d8bd18581efd                NaN           NaN
# 118  b4d50c88-abee-44b9-92d9-0aeb12b6149b                NaN           NaN
# 119  1feabe8c-3f44-4229-9ebe-94bedf184105                NaN           NaN
#
#          form_phone reason_why_not_billed_duplicate_column_name_1  \
# 100             NaN                                           NaN
# 101  (254) 225-3629                                           NaN
# 102             NaN                                           NaN
# 103  (757) 713-4235                                           NaN
# 104             NaN                                    Short Call
# 105             NaN                                           NaN
# 106             NaN                                    Short Call
# 107  (301) 775-5732                                           NaN
# 108  (352) 445-0921                                           NaN
# 109  (443) 350-2188                                           NaN
# 110             NaN                                           NaN
# 111  (614) 226-4408                                           NaN
# 112  (215) 406-0633                                           NaN
# 113  (502) 229-9126                                           NaN
# 114             NaN                                           NaN
# 115  (205) 270-2814                                           NaN
# 116  (505) 266-6261                                           NaN
# 117  (571) 245-4886                                           NaN
# 118  (610) 762-6276                                           NaN
# 119  (571) 577-3082                                           NaN
#
#     referral_path conaffid_medium                     form_email  \
# 100          call             PPC                            NaN
# 101          form             PPC           bouncedatazz@aol.com
# 102          call         Organic                            NaN
# 103          form         Organic       keithbeasley55@gmail.com
# 104          call              TV                            NaN
# 105         click         Organic                            NaN
# 106          call              TV                            NaN
# 107          form             PPC          steinselwyn@yahoo.com
# 108          form          Social  delaurentis.william@gmail.com
# 109          form             PPC          willbattaglia@aol.com
# 110         click         Organic                            NaN
# 111          form             PPC                 klas58@aol.com
# 112          form             PPC             lpat4225@gmail.com
# 113          form             PPC         wperkins5534@gmail.com
# 114         click         Organic                            NaN
# 115          form             PPC        michaelresh49@yahoo.com
# 116          form             PPC          roncordova7@gmail.com
# 117          form         Organic       claudiaabby3@hotmail.com
# 118          form             PPC             epastel777@rcn.com
# 119          form             PPC            vjha@protonmail.com
#
#      phone_duration        form_city    form_state crm_status  \
# 100           506.0              NaN           NaN    unknown
# 101             NaN           AUSTIN            TX   accepted
# 102          1746.0              NaN           NaN    unknown
# 103             NaN         Yorktown            VA   accepted
# 104             8.0              NaN           NaN    unknown
# 105             NaN              NaN           NaN    unknown
# 106            20.0              NaN           NaN    unknown
# 107             NaN  West Palm Beach            FL   accepted
# 108             NaN        DUNNELLON            FL   accepted
# 109             NaN           ELKTON            MD   accepted
# 110             NaN              NaN           NaN    unknown
# 111             NaN         COLUMBUS            OH   accepted
# 112             NaN     PHILADELPHIA            PA   accepted
# 113             NaN     LAWRENCEBURG            KY   accepted
# 114             NaN              NaN           NaN    unknown
# 115             NaN            BERRY            AL   accepted
# 116             NaN      ALBUQUERQUE            NM   accepted
# 117             NaN       Woodbridge      Virginia   accepted
# 118             NaN        Bethlehem  Pennsylvania   accepted
# 119             NaN          ASHBURN            VA   accepted
#
#     reason_why_not_billed  cpl_revenue
# 100                   NaN         45.0
# 101                   NaN         45.0
# 102                   NaN         45.0
# 103                   NaN         45.0
# 104            Short Call          0.0
# 105                   NaN          0.0
# 106            Short Call          0.0
# 107                   NaN         45.0
# 108                   NaN         45.0
# 109                   NaN         45.0
# 110                   NaN          0.0
# 111                   NaN         45.0
# 112                   NaN         45.0
# 113                   NaN         45.0
# 114                   NaN          0.0
# 115                   NaN         45.0
# 116                   NaN         45.0
# 117                   NaN         45.0
# 118                   NaN         45.0
# 119                   NaN         45.0

# %%
ca_report_small['accepted_referral'] = (
    ca_report_small[ca_report_reason_why_not_billed_field_name].apply(is_blank_or_nan))

#print(ca_report_small)

ca_report_small_accepted = (ca_report_small.loc[(ca_report_small['accepted_referral']) & 
                                            (ca_report_small[ca_report_phone_duration_field_name]>=60)]).copy()
print(ca_report_small_accepted)
# Out:
# nan
# nan
# nan
# nan
# Short Call
# nan
# Short Call
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#       submitted_cst_date            campaign_name  raw_referral_id  \
# 100  2019-08-01 00:00:00  Endurance Auto Warranty          7614028
# 102  2019-08-01 00:00:00  Endurance Auto Warranty          7614534
#
#            object uuid originating_number  phone_number form_phone  \
# 100         My CA  NaN       +16145600872  1.855707e+10        NaN
# 102  Buyers Guide  NaN       +18086887650  1.877370e+10        NaN
#
#     reason_why_not_billed_duplicate_column_name_1 referral_path  \
# 100                                           NaN          call
# 102                                           NaN          call
#
#     conaffid_medium form_email  phone_duration form_city form_state  \
# 100             PPC        NaN           506.0       NaN        NaN
# 102         Organic        NaN          1746.0       NaN        NaN
#
#     crm_status reason_why_not_billed  cpl_revenue  accepted_referral
# 100    unknown                   NaN         45.0               True
# 102    unknown                   NaN         45.0               True
